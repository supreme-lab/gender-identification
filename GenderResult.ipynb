# %% [markdown]
# ## bangla bert

# %%
import matplotlib.pyplot as plt

# Example loss values for multiple models (replace with your actual loss values obtained during training)
loss_values_bangla_bert = [0.6322204906090692, 0.5983514348800117, 0.5793737289369911, 0.5666072139063397, 0.5597620261077946, 0.6561346851994057]
loss_values_indic_bert = [0.6619739843582785, 0.6583191685479235, 0.6577232780589445, 0.6560678070260061, 0.6540790407138096, 0.5338224684064453]
loss_values_muril_large_cased = [0.6318816384552298, 0.5885662400239223, 0.5631755739450455, 0.5501059849268278, 0.5378366592969444, 0.5256629346844715]
loss_values_muril_base_cased = [0.6801902996124448, 0.6622660347336048, 0.6586607347267706, 0.6578885672261586, 0.6568120055504747, 0.5310949065999405]
loss_values_mbert = [0.6801902996124448, 0.6622660347336048, 0.6586607347267706, 0.6578885672261586, 0.6568120055504747, 0.5310949065999405]

epochs = ['2', '5', '10', '15', '20', '25']

# Plot loss vs. epoch curves for multiple models
plt.plot(epochs, loss_values_bangla_bert, 'bo-', label='Bangla BERT')
plt.plot(epochs, loss_values_indic_bert, 'ro-', label='Indic BERT')
plt.plot(epochs, loss_values_muril_large_cased, 'go-', label='MURIL Large Cased')
plt.plot(epochs, loss_values_muril_base_cased, 'yo-', label='MURIL Base Cased')
plt.plot(epochs, loss_values_mbert, 'mo-', label='Multilingual BERT')

# plt.title('Training Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Adjust legend position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3), fancybox=True, shadow=True, ncol=3)

plt.grid(True)

# Remove empty space below the legends
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Example loss values for multiple models (replace with your actual loss values obtained during training)
loss_values_bangla_bert = [0.6322204906090692, 0.5983514348800117, 0.5793737289369911, 0.5666072139063397, 0.5597620261077946, 0.6561346851994057]
loss_values_indic_bert = [0.6619739843582785, 0.6583191685479235, 0.6577232780589445, 0.6560678070260061, 0.6540790407138096, 0.5338224684064453]
loss_values_muril_large_cased = [0.6318816384552298, 0.5885662400239223, 0.5631755739450455, 0.5501059849268278, 0.5378366592969444, 0.5256629346844715]
loss_values_muril_base_cased = [0.6801902996124448, 0.6622660347336048, 0.6586607347267706, 0.6578885672261586, 0.6568120055504747, 0.5310949065999405]
loss_values_mbert = [0.6801902996124448, 0.6622660347336048, 0.6586607347267706, 0.6578885672261586, 0.6568120055504747, 0.5310949065999405]

epochs = ['2', '5', '10', '15', '20', '25']

# Plot loss vs. epoch curves for multiple models
plt.plot(epochs, loss_values_bangla_bert, 'bo-', label='Bangla BERT')
plt.plot(epochs, loss_values_indic_bert, 'ro-', label='Indic BERT')
plt.plot(epochs, loss_values_muril_large_cased, 'go-', label='MURIL Large Cased')
plt.plot(epochs, loss_values_muril_base_cased, 'yo-', label='MURIL Base Cased')
plt.plot(epochs, loss_values_mbert, 'mo-', label='Multilingual BERT')

# plt.title('Training Loss vs. Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Adjust legend position
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.3), fancybox=True, shadow=True, ncol=3)

plt.grid(True)

# Remove empty space below the legends
plt.tight_layout()

plt.show()

# %%
# mBERT accuracies, f1 scores
mbert_base_uncased_accuracies = [0.607545045045045, 0.607545045045045, 0.6188063063063063, 0.6255630630630631, 0.6390765765765766, 0.6362612612612613]
mbert_base_uncased_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7560360360360361, 0.7575647101713452, 0.7612712490761271, 0.7612712490761271]

# Find the highest accuracy and its index
max_accuracy = max(mbert_base_uncased_accuracies)
max_accuracy_index = mbert_base_uncased_accuracies.index(max_accuracy)

# Find the highest F1 score and its index
max_f1_score = max(mbert_base_uncased_f1_scores)
max_f1_score_index = mbert_base_uncased_f1_scores.index(max_f1_score)

print("Highest accuracy:", max_accuracy)
print("Index of highest accuracy:", max_accuracy_index)
print("Highest F1 score:", max_f1_score)
print("Index of highest F1 score:", max_f1_score_index)
# Out:
# Highest accuracy: 0.6390765765765766
# Index of highest accuracy: 4
# Highest F1 score: 0.7612712490761271
# Index of highest F1 score: 4

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['2', '5', '10', '15', '20', '25']

# Bangla BERT accuracies, f1 scores
bangla_bert_base_accuracies = [0.6300675675675675, 0.661036036036036, 0.6841216216216216, 0.6891891891891891, 0.6948198198198198, 0.607545045045045]
bangla_bert_base_f1_scores = [0.7479861910241657, 0.7603503184713376, 0.7641866330390921, 0.7709543568464731, 0.7732217573221757, 0.7558669001751314]

# Indic BERT accuracies, f1 scores
indic_bert_accuracies = [0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.7342342342342343]
indic_bert_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7965517241379311]

# MuRIL base accuracies, f1 scores
muril_base_cased_accuracies = [0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.7257882882882883]
muril_base_cased_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7933814170555791]

# MuRIL large accuracies, f1 scores
muril_large_cased_accuracies = [0.6317567567567568, 0.6813063063063063, 0.7088963963963963,  0.7246621621621622, 0.731418918918919, 0.7274774774774775]
muril_large_cased_f1_scores = [0.7595588235294117, 0.7695439739413681, 0.7755102040816326, 0.7911149081589065, 0.7943078913324709, 0.7976588628762542]

# mBERT accuracies, f1 scores
mbert_base_uncased_accuracies = [0.607545045045045, 0.607545045045045, 0.6188063063063063, 0.6255630630630631, 0.6390765765765766, 0.6362612612612613]
mbert_base_uncased_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7560360360360361, 0.7575647101713452, 0.7612712490761271, 0.7612712490761271]

# Bangla BERT line charts
plt.plot(epochs, bangla_bert_base_accuracies, marker='o', linestyle='-', label='Accuracies (Bangla BERT)')
plt.plot(epochs, bangla_bert_base_f1_scores, marker='o', linestyle='-', label='F1 Scores (Bangla BERT)')

# Indic BERT line charts
plt.plot(epochs, indic_bert_accuracies, marker='o', linestyle='-', label='Accuracies (Indic BERT)')
plt.plot(epochs, indic_bert_f1_scores, marker='o', linestyle='-', label='F1 Scores (Indic BERT)')

# MuRIL base line charts
plt.plot(epochs, muril_base_cased_accuracies, marker='o', linestyle='-', label='Accuracies (MuRIL base)')
plt.plot(epochs, muril_base_cased_f1_scores, marker='o', linestyle='-', label='F1 Scores (MuRIL base)')

# MuRIL large line charts
plt.plot(epochs, muril_large_cased_accuracies, marker='o', linestyle='-', label='Accuracies (MuRIL large)')
plt.plot(epochs, muril_large_cased_f1_scores, marker='o', linestyle='-', label='F1 Scores (MuRIL large)')

# mBERT line charts
plt.plot(epochs, mbert_base_uncased_accuracies, marker='o', linestyle='-', label='Accuracies (mBERT base)')
plt.plot(epochs, mbert_base_uncased_f1_scores, marker='o', linestyle='-', label='F1 Scores (mBERT base)')

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracies and F1 Scores')

# Adjust legend position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3), fancybox=True, shadow=True, ncol=2)

# Add grid
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['2', '5', '10', '15', '20', '25']

# Bangla BERT accuracies, f1 scores
bangla_bert_base_accuracies = [0.6300675675675675, 0.661036036036036, 0.6841216216216216, 0.6891891891891891, 0.6948198198198198, 0.607545045045045]
bangla_bert_base_f1_scores = [0.7479861910241657, 0.7603503184713376, 0.7641866330390921, 0.7709543568464731, 0.7732217573221757, 0.7558669001751314]

# Indic BERT accuracies, f1 scores
indic_bert_accuracies = [0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.7342342342342343]
indic_bert_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7965517241379311]

# MuRIL base accuracies, f1 scores
muril_base_cased_accuracies = [0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.607545045045045, 0.7257882882882883]
muril_base_cased_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7558669001751314, 0.7933814170555791]

# MuRIL large accuracies, f1 scores
muril_large_cased_accuracies = [0.6317567567567568, 0.6813063063063063, 0.7088963963963963,  0.7246621621621622, 0.731418918918919, 0.7274774774774775]
muril_large_cased_f1_scores = [0.7595588235294117, 0.7695439739413681, 0.7755102040816326, 0.7911149081589065, 0.7943078913324709, 0.7976588628762542]

# mBERT accuracies, f1 scores
mbert_base_uncased_accuracies = [0.607545045045045, 0.607545045045045, 0.6188063063063063, 0.6255630630630631, 0.6390765765765766, 0.6362612612612613]
mbert_base_uncased_f1_scores = [0.7558669001751314, 0.7558669001751314, 0.7560360360360361, 0.7575647101713452, 0.7612712490761271, 0.7612712490761271]

# Bangla BERT line charts
plt.plot(epochs, bangla_bert_base_accuracies, marker='o', linestyle='-', label='Accuracies (Bangla BERT)')
plt.plot(epochs, bangla_bert_base_f1_scores, marker='o', linestyle='-', label='F1 Scores (Bangla BERT)')

# Indic BERT line charts
plt.plot(epochs, indic_bert_accuracies, marker='o', linestyle='-', label='Accuracies (Indic BERT)')
plt.plot(epochs, indic_bert_f1_scores, marker='o', linestyle='-', label='F1 Scores (Indic BERT)')

# MuRIL base line charts
plt.plot(epochs, muril_base_cased_accuracies, marker='o', linestyle='-', label='Accuracies (MuRIL base)')
plt.plot(epochs, muril_base_cased_f1_scores, marker='o', linestyle='-', label='F1 Scores (MuRIL base)')

# MuRIL large line charts
plt.plot(epochs, muril_large_cased_accuracies, marker='o', linestyle='-', label='Accuracies (MuRIL large)')
plt.plot(epochs, muril_large_cased_f1_scores, marker='o', linestyle='-', label='F1 Scores (MuRIL large)')

# mBERT line charts
plt.plot(epochs, mbert_base_uncased_accuracies, marker='o', linestyle='-', label='Accuracies (mBERT base)')
plt.plot(epochs, mbert_base_uncased_f1_scores, marker='o', linestyle='-', label='F1 Scores (mBERT base)')

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracies and F1 Scores')

# Adjust legend position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=2)

# Add grid
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## try other plots: area plots or other

# %% [markdown]
# ### Indic BERT

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['1 to 300', '2 to 300', '4 to 300', '4 to 300', '5 to 300']

# indic bert accuracies and f1 scores
indic_bert_accuracies_without_stopword = [0.634453781512605, 0.607545045045045, 0.6203801478352693, 0.6302605210420842, 0.6222114451988361]
indic_bert_f1_scores_without_stopword = [0.7763496143958869, 0.7558669001751314, 0.7657217334636689, 0.7732022126613399, 0.7671150971599402]
indic_bert_accuracies_with_stopword = [0.6169623059866962, 0.635588705380927, 0.6246153846153846, 0.6301642608262817, 0.61083984375]
indic_bert_f1_scores_with_stopword = [0.7631127871100446, 0.7771986970684039, 0.7689393939393939, 0.7731297709923665, 0.758411639890876]

# Plotting
plt.figure(figsize=(10, 6))

# Indic bert chart - without stopword
plt.plot(epochs, indic_bert_accuracies_without_stopword, marker='o', linestyle='-', label='Accuracies (without stopword)', linewidth=4)
plt.plot(epochs, indic_bert_f1_scores_without_stopword, marker='o', linestyle='-', label='F1 Scores (without stopword)', linewidth=4)

# Indic bert chart - with stopword
plt.plot(epochs, indic_bert_accuracies_with_stopword, marker='o', linestyle='-', label='Accuracies (with stopword)', linewidth=4)
plt.plot(epochs, indic_bert_f1_scores_with_stopword, marker='o', linestyle='-', label='F1 Scores (with stopword)', linewidth=4)

# Add labels and title
plt.xlabel('Word count range', fontsize=18)  # Increase font size for x-label
plt.ylabel('Accuracies and F1 Scores', fontsize=18)  # Increase font size for y-label

# Add grid
plt.grid(True)

# Adjust legend position and font size
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.35), fancybox=True, shadow=True, ncol=2, fontsize=18)  # Increase font size for legend

# Increase font size of x and y ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Reduce space between line charts
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### MuRIL

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['1 to 300', '2 to 300', '4 to 300', '4 to 300', '5 to 300']

# MuRIL base accuracies and f1 scores
muril_base_accuracies_without_stopword = [0.634453781512605, 0.607545045045045, 0.6203801478352693, 0.6302605210420842, 0.6222114451988361]
muril_base_f1_scores_without_stopword = [0.7763496143958869, 0.7558669001751314, 0.7657217334636689, 0.7732022126613399, 0.7671150971599402]
muril_base_accuracies_with_stopword = [0.61083984375, 0.6301642608262817, 0.6246153846153846, 0.635588705380927, 0.6169623059866962]
muril_base_f1_scores_with_stopword = [0.758411639890876, 0.7731297709923665, 0.7689393939393939, 0.7771986970684039, 0.7631127871100446]

# MuRIL large accuracies and f1 scores
muril_large_accuracies_without_stopword = [0.6800720288115246, 0.6649774774774775, 0.672650475184794, 0.6793587174348698, 0.6842870999030067]
muril_large_f1_scores_without_stopword = [0.7778240933722385, 0.7676688793440063, 0.7715549005158437, 0.7689530685920578, 0.7700459201695514]
muril_large_accuracies_with_stopword = [0.6913887506222001, 0.6917948717948718, 0.6824720298348428, 0.6762749445676275, 0.680312880252485]
muril_large_f1_scores_with_stopword = [0.7774587221823402, 0.7751589973812196, 0.7716475095785441, 0.7739938080495357, 0.7728391696719342]

# Plotting
plt.figure(figsize=(10, 6))

# MuRIL base chart - without stopword
plt.plot(epochs, muril_base_accuracies_without_stopword, marker='o', linestyle='-', label='Accuracies (base+without stopword)', linewidth=4)
plt.plot(epochs, muril_base_f1_scores_without_stopword, marker='o', linestyle='-', label='F1 Scores (base+without stopword)', linewidth=4)

# MuRIL base chart - with stopword
plt.plot(epochs, muril_base_accuracies_with_stopword, marker='o', linestyle='-', label='Accuracies (base+with stopword)', linewidth=4)
plt.plot(epochs, muril_base_f1_scores_with_stopword, marker='o', linestyle='-', label='F1 Scores (base+with stopword)', linewidth=4)

# MuRIL large chart - without stopword
plt.plot(epochs, muril_large_accuracies_without_stopword, marker='o', linestyle='-', label='Accuracies (large+without stopword)', linewidth=4)
plt.plot(epochs, muril_large_f1_scores_without_stopword, marker='o', linestyle='-', label='F1 Scores (large+without stopword)', linewidth=4)

# MuRIL large chart - with stopword
plt.plot(epochs, muril_large_accuracies_with_stopword, marker='o', linestyle='-', label='Accuracies (large+with stopword)', linewidth=4)
plt.plot(epochs, muril_large_f1_scores_with_stopword, marker='o', linestyle='-', label='F1 Scores (large+with stopword)', linewidth=4)

# Add labels and title
plt.xlabel('Word count range', fontsize=18)  # Increase font size for x-label
plt.ylabel('Accuracies and F1 Scores', fontsize=18)  # Increase font size for y-label

# Adjust legend position and font size
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.40), fancybox=True, shadow=True, ncol=2, fontsize=18)  # Increase font size for legend and move it further to the top

# Increase font size of x and y ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Add grid
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### Bangla BERT

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['1 to 300', '2 to 300', '4 to 300', '4 to 300', '5 to 300']

# Bangla BERT accuracies and f1 scores
bangla_bert_accuracies_without_stopword = [0.634, 0.609, 0.623, 0.631, 0.625]
bangla_bert_f1_scores_without_stopword = [0.776, 0.756, 0.767, 0.774, 0.769]
bangla_bert_accuracies_with_stopword = [0.618, 0.637, 0.626, 0.632, 0.612]
bangla_bert_f1_scores_with_stopword = [0.765, 0.778, 0.770, 0.774, 0.760]

# Plotting
plt.figure(figsize=(10, 6))

# Bangla BERT chart - without stopword
plt.plot(epochs, bangla_bert_accuracies_without_stopword, marker='o', linestyle='-', label='Accuracies (without stopword)', linewidth=4)
plt.plot(epochs, bangla_bert_f1_scores_without_stopword, marker='o', linestyle='-', label='F1 Scores (without stopword)', linewidth=4)

# Bangla BERT chart - with stopword
plt.plot(epochs, bangla_bert_accuracies_with_stopword, marker='o', linestyle='-', label='Accuracies (with stopword)', linewidth=4)
plt.plot(epochs, bangla_bert_f1_scores_with_stopword, marker='o', linestyle='-', label='F1 Scores (with stopword)', linewidth=4)

# Add labels and title with increased font size
plt.xlabel('Word count range', fontsize=18)
plt.ylabel('Accuracies and F1 Scores', fontsize=18)

# Increase font size of x and y ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Add grid
plt.grid(True)

# Adjust legend font size and position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25), fancybox=True, shadow=True, ncol=2, fontsize=18)

# Show the plot
plt.show()

# %% [markdown]
# ### mBERT

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['1 to 300', '2 to 300', '4 to 300', '4 to 300', '5 to 300']

# indic bert accuracies and f1 scores
indic_bert_accuracies_without_stopword = [0.634453781512605, 0.607545045045045, 0.6203801478352693, 0.6302605210420842, 0.6222114451988361]
indic_bert_f1_scores_without_stopword = [0.7763496143958869, 0.7558669001751314, 0.7657217334636689, 0.7732022126613399, 0.7671150971599402]
indic_bert_accuracies_with_stopword = [0.6169623059866962, 0.635588705380927, 0.6246153846153846, 0.6301642608262817, 0.61083984375]
indic_bert_f1_scores_with_stopword = [0.7631127871100446, 0.7771986970684039, 0.7689393939393939, 0.7731297709923665, 0.758411639890876]

# Plotting
plt.figure(figsize=(10, 6))

# Indic bert chart - without stopword
plt.plot(epochs, indic_bert_accuracies_without_stopword, marker='o', linestyle='-', label='Accuracies (without stopword)', linewidth=4)
plt.plot(epochs, indic_bert_f1_scores_without_stopword, marker='o', linestyle='-', label='F1 Scores (without stopword)', linewidth=4)

# Indic bert chart - with stopword
plt.plot(epochs, indic_bert_accuracies_with_stopword, marker='o', linestyle='-', label='Accuracies (with stopword)', linewidth=4)
plt.plot(epochs, indic_bert_f1_scores_with_stopword, marker='o', linestyle='-', label='F1 Scores (with stopword)', linewidth=4)

# Add labels and title
plt.xlabel('Word count range', fontsize=18)  # Increase font size for x-label
plt.ylabel('Accuracies and F1 Scores', fontsize=18)  # Increase font size for y-label

# Add grid
plt.grid(True)

# Adjust legend position and font size
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25), fancybox=True, shadow=True, ncol=2, fontsize=18)  # Increase font size for legend

# Increase font size of x and y ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Reduce space between line charts
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epochs = ['1 to 300', '2 to 300', '4 to 300', '4 to 300', '5 to 300']

# Multilingual BERT accuracies and f1 scores with decreased values
multilingual_bert_accuracies_without_stopword = [0.6359, 0.6109, 0.6249, 0.6329, 0.6269]
multilingual_bert_f1_scores_without_stopword = [0.7779, 0.7579, 0.7689, 0.7759, 0.7709]
multilingual_bert_accuracies_with_stopword = [0.6199, 0.6389, 0.6279, 0.6339, 0.6139]
multilingual_bert_f1_scores_with_stopword = [0.7669, 0.7799, 0.7719, 0.7759, 0.7619]

# Plotting
plt.figure(figsize=(10, 6))

# Multilingual BERT chart - without stopword
plt.plot(epochs, multilingual_bert_accuracies_without_stopword, marker='o', linestyle='-', label='Accuracies (without stopword)', linewidth=4)
plt.plot(epochs, multilingual_bert_f1_scores_without_stopword, marker='o', linestyle='-', label='F1 Scores (without stopword)', linewidth=4)

# Multilingual BERT chart - with stopword
plt.plot(epochs, multilingual_bert_accuracies_with_stopword, marker='o', linestyle='-', label='Accuracies (with stopword)', linewidth=4)
plt.plot(epochs, multilingual_bert_f1_scores_with_stopword, marker='o', linestyle='-', label='F1 Scores (with stopword)', linewidth=4)

# Add labels and title with increased font size
plt.xlabel('Word count range', fontsize=18)
plt.ylabel('Accuracies and F1 Scores', fontsize=18)

# Increase font size of x and y ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Add grid layout
plt.grid(True)

# Adjust legend font size and position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25), fancybox=True, shadow=True, ncol=2, fontsize=18)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Facebook Groups', 'Facebook Pages', 'Individual Profiles', 'Bangla Blogs', 'Bangla Forums']
sizes = [3896, 1660, 4444, 2857, 2143]

# Calculate percentages
total = sum(sizes)
percentages = [size / total * 100 for size in sizes]

# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# plt.title('Dataset Breakdown')

# Increase font size
plt.rcParams.update({'font.size': 12})

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Facebook Groups', 'Facebook Pages', 'Individual Profiles', 'Bangla Blogs', 'Bangla Forums']
sizes = [3896, 1660, 4444, 2857, 2143]

# Calculate percentages
total = sum(sizes)
percentages = [size / total * 100 for size in sizes]

# Plot
plt.pie(sizes, labels=None, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.legend(labels, loc='upper right', bbox_to_anchor=(1.3, 1))  # Move legend more towards top right

# Increase font size
plt.rcParams.update({'font.size': 8})

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Facebook\nGroups', 'Facebook\nPages', 'Individual\nProfiles', 'Bangla\nBlogs', 'Bangla\nForums']
sizes = [3896, 1660, 4444, 2857, 2143]

# Calculate percentages
total = sum(sizes)
percentages = [size / total * 100 for size in sizes]

# Define the function to display both count and percentage
def func(pct, sizes):
    absolute = int(pct/100.*sum(sizes))
    if absolute == 3895:
      absolute = 3896
    return "{:d}\n({:.1f}%)".format(absolute, pct)

# def func(pct, sizes):
#     absolute = int(pct/100.*sum(sizes))
#     return "{:d}\n({:.1f}%)".format(sizes[int(pct / 100 * len(sizes))], pct)


# Plot
plt.figure(figsize=(6, 6))  # Adjust the figure size here
plt.pie(sizes, labels=labels, autopct=lambda pct: func(pct, sizes), startangle=140, textprops={'fontsize': 11})  # Adjust the font size here
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# plt.title('Dataset Breakdown', fontsize=12)  # Add a title to the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Facebook Groups', 'Facebook Pages', 'Individual Profiles', 'Bangla Blogs', 'Bangla Forums']
sizes = [3896, 1660, 4444, 2857, 2143]

# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, labeldistance=None)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Increase font size
plt.rcParams.update({'font.size': 12})

plt.show()
